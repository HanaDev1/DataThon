# %%
#import packages
import pandas as pd

# %%
main_data = pd.read_csv("Main-dataset.csv")

# %%
main_data.head()
# Out:
#    Unnamed: 0                                 measure      location     sex  \
# 0     3060356  DALYs (Disability-Adjusted Life Years)  Saudi Arabia    Male
# 1     3060357  DALYs (Disability-Adjusted Life Years)  Saudi Arabia  Female
# 2     3060358  DALYs (Disability-Adjusted Life Years)  Saudi Arabia    Male
# 3     3060359  DALYs (Disability-Adjusted Life Years)  Saudi Arabia  Female
# 4     3060360  DALYs (Disability-Adjusted Life Years)  Saudi Arabia    Male
#
#                 age                    cause              rei_value   metric  \
# 0  Age-standardized  Cardiovascular diseases  Low physical activity  Percent
# 1  Age-standardized  Cardiovascular diseases  Low physical activity  Percent
# 2  Age-standardized  Cardiovascular diseases  Low physical activity     Rate
# 3  Age-standardized  Cardiovascular diseases  Low physical activity     Rate
# 4           95 plus  Cardiovascular diseases  Low physical activity   Number
#
# ...

# %%
second_data = pd.read_csv("Supplemental-dataset.csv")

# %%
second_data.head()
# Out:
#    Unnamed: 0                                 measure  location     sex  \
# 0           0  DALYs (Disability-Adjusted Life Years)  Portugal  Female
# 1           1  DALYs (Disability-Adjusted Life Years)  Portugal    Male
# 2           2  DALYs (Disability-Adjusted Life Years)  Portugal  Female
# 3           3  DALYs (Disability-Adjusted Life Years)  Portugal    Male
# 4           4  DALYs (Disability-Adjusted Life Years)  Portugal  Female
#
#                 age      cause                  rei_value   metric  year  \
# 0  Age-standardized  Neoplasms              Air pollution  Percent  2017
# 1  Age-standardized  Neoplasms              Air pollution     Rate  2017
# 2  Age-standardized  Neoplasms              Air pollution     Rate  2017
# 3  Age-standardized  Neoplasms  Other environmental risks  Percent  2017
# 4  Age-standardized  Neoplasms  Other environmental risks  Percent  2017
#
#          val      upper     lower rei_type
# 0   0.005371   0.010512  0.000505     Risk
# ...

# %%
#countries
second_data.location.value_counts()
# Out:
# Saudi Arabia                      4532
# Guam                              3364
# Bosnia and Herzegovina            3352
# Tonga                             3350
# Czech Republic                    3342
# Uzbekistan                        3302
# Papua New Guinea                  3302
# Burkina Faso                      3292
# Vietnam                           3292
# Cameroon                          3288
# Kiribati                          3286
# Maldives                          3280
# Mongolia                          3280
# Indonesia                         3278
# Mauritius                         3274
# Georgia                           3274
# Sierra Leone                      3270
# South Korea                       3262
# Nigeria                           3262
# Mali                              3260
# Latvia                            3250
# Yemen                             3246
# Russian Federation                3240
# Tunisia                           3238
# ...

# %%
#years, data is from 2007 to 2017
second_data.year.value_counts()
# Out:
# 2017    80338
# 2016    80338
# 2015    80338
# 2014    80338
# 2008    80338
# 2007    80338
# 2013    64224
# 2009    31802
# 2012    14584
# 2011    13604
# 2010    13604
# Name: year, dtype: int64

# %%
second_data.cause.value_counts()
#Self-harm and interpersonal violence, 24664
# Out:
# Diarrheal diseases                              111540
# Cardiovascular diseases                          60862
# Neoplasms                                        58116
# Diabetes and kidney diseases                     54946
# Lower respiratory infections                     34320
# Respiratory infections and tuberculosis          32828
# Sense organ diseases                             24798
# Self-harm and interpersonal violence             24664
# Chronic respiratory diseases                     22144
# Digestive diseases                               22140
# Musculoskeletal disorders                        22120
# Neurological disorders                           22092
# Transport injuries                               22000
# Unintentional injuries                           21984
# Substance use disorders                          16472
# Mental disorders                                 13784
# HIV/AIDS and sexually transmitted infections     13730
# ...

# %%
main_data.cause.value_counts()
#Self-harm and interpersonal violence,528
# Out:
# Diarrheal diseases                              18590
# Lower respiratory infections                     5720
# Neoplasms                                        1452
# Diabetes and kidney diseases                     1364
# Cardiovascular diseases                          1342
# Respiratory infections and tuberculosis           924
# Chronic respiratory diseases                      572
# Digestive diseases                                572
# Sense organ diseases                              561
# Self-harm and interpersonal violence              528
# Substance use disorders                           528
# Unintentional injuries                            506
# Transport injuries                                506
# Neurological disorders                            506
# HIV/AIDS and sexually transmitted infections      440
# Mental disorders                                  440
# Musculoskeletal disorders                         440
# ...

# %%
#Alcohol use
#Drug use
#High body-mass index
#High systolic blood, pressure
#Tobacco smoking
#Physical inactivity and low physical activity
#
#حالة الوالدين التعليمية
#حالة الوالدين الاجتماعي

# %% [markdown]
# 1. Self-harm by firearm
# 2. Self-harm by other specified
# means
# 3. Interpersonal violence Physical violence by firearm
# 4. Physical violence by sharp object
# 5. Sexual violence
# 6. Physical violence by other means

# %% [markdown]
# ### Risks
# * Behavioral risks
# * Child and maternal malnutrition
# * Tobacco
# * Alcohol use
# * Drug use
# * Dietary risks
# * Intimate partner violence
# * Childhood maltreatment
# * Unsafe sex
# * Low physical activity

# %% [markdown]
# ### Solutions:
# * وضع قوانين و تطبيقها فعلياً
# * الوصول للمناطق النائية
# * توعية المعرضين لخطر العنف بحقوقهم
# * وصل مستشارين و اخصائيين نفسيين للمتعرضين للعنف
# * في حال قررنا يكون حلنا لمشلكة العنف تطبيق، نحتاج نستعجل في ايجاد العلاقة

# %% [markdown]
# في التقرير المقدم، ينبغي شرح الفكرة بوضوح. حيث يوضح فيه الفريق المشكلة المراد تقديم حل لها. بعد تحليل البيانات، قم بتحديد مشكلة محددة، قدم وصفاً دقيقا لها، بين الأسس المستخدمة لتحديدها، ثم اقترح حلولاً مناسبة.
# قدم شرحاً مفصلاً للحل الذي ترغب بتقديمه، بين نوع هذا  الحل، هل يتضمن الحل تغيير في قانون؟ نظام؟تطوير برنامج؟ … إلخ

# %% [markdown]
# ### Questions:
# * ...........
# * ...........
# * ...........
# * ...........
# * ...........
# * ...........
# * ...........
